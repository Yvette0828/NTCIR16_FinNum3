# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
import pandas as pd
import numpy as np

# %%
combine = pd.read_excel('/content/drive/MyDrive/NTPU/NTCIR/FinNum3/EA_zh_combine2.xlsx', index_col = [0])
combine
# Out:
#                                                    text  ...    aug
# 0     展望2019年，雖中美貿易戰使各產業資本支出持續觀望，然食衣需求依然持續提升，根據Eurom...  ...    0.0
# 1     展望2019年，雖中美貿易戰使各產業資本支出持續觀望，然食衣需求依然持續提升，根據Eurom...  ...    0.0
# 2     展望2019年，雖中美貿易戰使各產業資本支出持續觀望，然食衣需求依然持續提升，根據Eurom...  ...    0.0
# 3     展望2019年，雖中美貿易戰使各產業資本支出持續觀望，然食衣需求依然持續提升，根據Eurom...  ...    0.0
# 4     展望2019年，雖中美貿易戰使各產業資本支出持續觀望，然食衣需求依然持續提升，根據Eurom...  ...    0.0
# ...                                                 ...  ...    ...
# 4688  集團公佈銷售收入超過100億人民幣，大幅增長170%以上。集團表示銷售收入上升主要由於產業互...  ...    0.0
# 4689  集團公佈銷售收入超過100億人民幣，大幅增長170%以上。集團表示銷售收入上升主要由於產業互...  ...    0.0
# 4690  集團公佈銷售收入超過100億人民幣，大幅增長170%以上。集團表示銷售收入上升主要由於產業互...  ...    0.0
# 4690                                                NaN  ...  225.0
# 4690                                                NaN  ...    NaN
#
# [4693 rows x 14 columns]

# %%
fragment = combine[combine['fragment'].notna()]
fragment
# Out:
#                                                      text  ...                                           fragment
# 7.0     展望2019年，雖中美貿易戰使各產業資本支出持續觀望，然食衣需求依然持續提升，根據Eurom...  ...                                     2018年公司出貨量約4萬台
# 15.0    近年來一般服飾走向低價、多樣化方向發展，高價機能衣因運動風氣盛行需求也有所增加，市場對服飾生...  ...         預估2019年稅後EPS5.11元，目前PER10倍，位於歷史PER9倍~16倍下緣
# 16.0    近年來一般服飾走向低價、多樣化方向發展，高價機能衣因運動風氣盛行需求也有所增加，市場對服飾生...  ...         預估2019年稅後EPS5.11元，目前PER10倍，位於歷史PER9倍~16倍下緣
# 17.0    近年來一般服飾走向低價、多樣化方向發展，高價機能衣因運動風氣盛行需求也有所增加，市場對服飾生...  ...         預估2019年稅後EPS5.11元，目前PER10倍，位於歷史PER9倍~16倍下緣
# 19.0    近年來一般服飾走向低價、多樣化方向發展，高價機能衣因運動風氣盛行需求也有所增加，市場對服飾生...  ...                            目標價61元(2019年EPS*PER12倍)
# ...                                                   ...  ...                                                ...
# 4655.0  創意一年tapeout數目約20~30項，目前與人工智慧相關的數目為11個，包括1項為7nm...  ...  公司2018年人工智慧營收比重約7%~8%，預計2019年比重可望提升至10%，主要將於20...
# ...

# %%
fragment.columns = ['text', 'target_numeral', 'offset', 'category', 'claim_report', 'claim_baseline', 'claim_dr', 'claim_aug', '', 'EA category', 'fragment']
EA_category = fragment.groupby('EA category')
EA_category = pd.DataFrame(EA_category.size())
EA_category.columns = ['total']
EA_category
# Out:
#              total
# EA category
# 1.0             77
# 2.0              4
# 3.0             68
# 4.0             72

# %%
# !pip install -U kaleido
import seaborn
import plotly.express as px
import kaleido

# %%
groupby_category = fragment.groupby('category')
category_size = pd.DataFrame(groupby_category.size().sort_values())
category_size.columns = ['total']
category_size
# Out:
#                    total
# category
# Product Number         3
# None                   5
# Quantity_relative      5
# date                  14
# price                 14
# Quantity_absolute     33
# relative              73
# money                 95
# absolute             110

# %%
fig = px.bar(category_size, x='total', y=category_size.index, text_auto = True)
fig.show()
# fig.write_image(fig, '/content/drive/MyDrive/NTPU/NTCIR/FinNum3/EA_zh_category.png', engine = 'kaleido', scale = 5) # , engine = 'kaleido'
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax) {MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
# ...

# %%
report = pd.read_json('/content/drive/MyDrive/NTPU/NTCIR/FinNum3/result/Chinese_Report_test.json')
report
# Out:
#                                                    text  ...  claim
# 0     展望2019年，雖中美貿易戰使各產業資本支出持續觀望，然食衣需求依然持續提升，根據Eurom...  ...      0
# 1     展望2019年，雖中美貿易戰使各產業資本支出持續觀望，然食衣需求依然持續提升，根據Eurom...  ...      1
# 2     展望2019年，雖中美貿易戰使各產業資本支出持續觀望，然食衣需求依然持續提升，根據Eurom...  ...      0
# 3     展望2019年，雖中美貿易戰使各產業資本支出持續觀望，然食衣需求依然持續提升，根據Eurom...  ...      1
# 4     展望2019年，雖中美貿易戰使各產業資本支出持續觀望，然食衣需求依然持續提升，根據Eurom...  ...      1
# ...                                                 ...  ...    ...
# 4686  集團公佈銷售收入超過100億人民幣，大幅增長170%以上。集團表示銷售收入上升主要由於產業互...  ...      0
# 4687  集團公佈銷售收入超過100億人民幣，大幅增長170%以上。集團表示銷售收入上升主要由於產業互...  ...      1
# 4688  集團公佈銷售收入超過100億人民幣，大幅增長170%以上。集團表示銷售收入上升主要由於產業互...  ...      0
# 4689  集團公佈銷售收入超過100億人民幣，大幅增長170%以上。集團表示銷售收入上升主要由於產業互...  ...      1
# 4690  集團公佈銷售收入超過100億人民幣，大幅增長170%以上。集團表示銷售收入上升主要由於產業互...  ...      1
#
# [4691 rows x 5 columns]

# %%
print(report.groupby('claim').size())
# Out:
# claim
# 0    3684
# 1    1007
# dtype: int64

# %%
report.columns = ['text', ' target_numeral', 'category', 'offset', 'claim_report'] #, 'claim_baseline', 'claim_dr', 'claim_translation'
report

# %%
df = pd.read_excel('/content/drive/MyDrive/NTPU/NTCIR/FinNum3/dataset/EA_zh_combine.xlsx', index_col = [0])
df
# Out:
#                                                    text  ...                                           fragment
# 0     展望2019年，雖中美貿易戰使各產業資本支出持續觀望，然食衣需求依然持續提升，根據Eurom...  ...  展望2019年，雖中美貿易戰使各產業資本支出持續觀望，然食衣需求依然持續提升，根據Eurom...
# 1     展望2019年，雖中美貿易戰使各產業資本支出持續觀望，然食衣需求依然持續提升，根據Eurom...  ...  展望2019年，雖中美貿易戰使各產業資本支出持續觀望，然食衣需求依然持續提升，根據Eurom...
# 2     展望2019年，雖中美貿易戰使各產業資本支出持續觀望，然食衣需求依然持續提升，根據Eurom...  ...  展望2019年，雖中美貿易戰使各產業資本支出持續觀望，然食衣需求依然持續提升，根據Eurom...
# 3     展望2019年，雖中美貿易戰使各產業資本支出持續觀望，然食衣需求依然持續提升，根據Eurom...  ...  展望2019年，雖中美貿易戰使各產業資本支出持續觀望，然食衣需求依然持續提升，根據Eurom...
# 4     展望2019年，雖中美貿易戰使各產業資本支出持續觀望，然食衣需求依然持續提升，根據Eurom...  ...  展望2019年，雖中美貿易戰使各產業資本支出持續觀望，然食衣需求依然持續提升，根據Eurom...
# ...                                                 ...  ...                                                ...
# 4686  集團公佈銷售收入超過100億人民幣，大幅增長170%以上。集團表示銷售收入上升主要由於產業互...  ...  集團公佈銷售收入超過100億人民幣，大幅增長170%以上。集團表示銷售收入上升主要由於產業互...
# ...

# %%
baseline = pd.read_json('/content/drive/MyDrive/NTPU/NTCIR/FinNum3/result/IMNTPU_Chinese_test_1.json')
baseline
# Out:
#                                                    text  ...  prediction
# 0     展望2019年，雖中美貿易戰使各產業資本支出持續觀望，然食衣需求依然持續提升，根據Eurom...  ...           0
# 1     展望2019年，雖中美貿易戰使各產業資本支出持續觀望，然食衣需求依然持續提升，根據Eurom...  ...           1
# 2     展望2019年，雖中美貿易戰使各產業資本支出持續觀望，然食衣需求依然持續提升，根據Eurom...  ...           0
# 3     展望2019年，雖中美貿易戰使各產業資本支出持續觀望，然食衣需求依然持續提升，根據Eurom...  ...           1
# 4     展望2019年，雖中美貿易戰使各產業資本支出持續觀望，然食衣需求依然持續提升，根據Eurom...  ...           1
# ...                                                 ...  ...         ...
# 4686  集團公佈銷售收入超過100億人民幣，大幅增長170%以上。集團表示銷售收入上升主要由於產業互...  ...           0
# 4687  集團公佈銷售收入超過100億人民幣，大幅增長170%以上。集團表示銷售收入上升主要由於產業互...  ...           1
# 4688  集團公佈銷售收入超過100億人民幣，大幅增長170%以上。集團表示銷售收入上升主要由於產業互...  ...           0
# 4689  集團公佈銷售收入超過100億人民幣，大幅增長170%以上。集團表示銷售收入上升主要由於產業互...  ...           1
# 4690  集團公佈銷售收入超過100億人民幣，大幅增長170%以上。集團表示銷售收入上升主要由於產業互...  ...           1
#
# [4691 rows x 4 columns]

# %%
dr = pd.read_json('/content/drive/MyDrive/NTPU/NTCIR/FinNum3/result/IMNTPU_Chinese_test_2.json')
dr
# Out:
#                                                    text  ...  prediction
# 0     展望2019年，雖中美貿易戰使各產業資本支出持續觀望，然食衣需求依然持續提升，根據Eurom...  ...           0
# 1     展望2019年，雖中美貿易戰使各產業資本支出持續觀望，然食衣需求依然持續提升，根據Eurom...  ...           1
# 2     展望2019年，雖中美貿易戰使各產業資本支出持續觀望，然食衣需求依然持續提升，根據Eurom...  ...           0
# 3     展望2019年，雖中美貿易戰使各產業資本支出持續觀望，然食衣需求依然持續提升，根據Eurom...  ...           1
# 4     展望2019年，雖中美貿易戰使各產業資本支出持續觀望，然食衣需求依然持續提升，根據Eurom...  ...           1
# ...                                                 ...  ...         ...
# 4686  集團公佈銷售收入超過100億人民幣，大幅增長170%以上。集團表示銷售收入上升主要由於產業互...  ...           0
# 4687  集團公佈銷售收入超過100億人民幣，大幅增長170%以上。集團表示銷售收入上升主要由於產業互...  ...           1
# 4688  集團公佈銷售收入超過100億人民幣，大幅增長170%以上。集團表示銷售收入上升主要由於產業互...  ...           0
# 4689  集團公佈銷售收入超過100億人民幣，大幅增長170%以上。集團表示銷售收入上升主要由於產業互...  ...           1
# 4690  集團公佈銷售收入超過100億人民幣，大幅增長170%以上。集團表示銷售收入上升主要由於產業互...  ...           1
#
# [4691 rows x 4 columns]

# %%
aug = pd.read_json('/content/drive/MyDrive/NTPU/NTCIR/FinNum3/result/IMNTPU_Chinese_test_3.json')
aug
# Out:
#                                                    text  ...  prediction
# 0     展望2019年，雖中美貿易戰使各產業資本支出持續觀望，然食衣需求依然持續提升，根據Eurom...  ...           0
# 1     展望2019年，雖中美貿易戰使各產業資本支出持續觀望，然食衣需求依然持續提升，根據Eurom...  ...           1
# 2     展望2019年，雖中美貿易戰使各產業資本支出持續觀望，然食衣需求依然持續提升，根據Eurom...  ...           0
# 3     展望2019年，雖中美貿易戰使各產業資本支出持續觀望，然食衣需求依然持續提升，根據Eurom...  ...           1
# 4     展望2019年，雖中美貿易戰使各產業資本支出持續觀望，然食衣需求依然持續提升，根據Eurom...  ...           1
# ...                                                 ...  ...         ...
# 4686  集團公佈銷售收入超過100億人民幣，大幅增長170%以上。集團表示銷售收入上升主要由於產業互...  ...           0
# 4687  集團公佈銷售收入超過100億人民幣，大幅增長170%以上。集團表示銷售收入上升主要由於產業互...  ...           1
# 4688  集團公佈銷售收入超過100億人民幣，大幅增長170%以上。集團表示銷售收入上升主要由於產業互...  ...           0
# 4689  集團公佈銷售收入超過100億人民幣，大幅增長170%以上。集團表示銷售收入上升主要由於產業互...  ...           1
# 4690  集團公佈銷售收入超過100億人民幣，大幅增長170%以上。集團表示銷售收入上升主要由於產業互...  ...           1
#
# [4691 rows x 4 columns]

# %%
report['claim_baseline'] = baseline.prediction
report['claim_dr'] = dr.prediction
report['claim_translation'] = aug.prediction
report
# Out:
#                                                    text  ...  claim_translation
# 0     展望2019年，雖中美貿易戰使各產業資本支出持續觀望，然食衣需求依然持續提升，根據Eurom...  ...                  0
# 1     展望2019年，雖中美貿易戰使各產業資本支出持續觀望，然食衣需求依然持續提升，根據Eurom...  ...                  1
# 2     展望2019年，雖中美貿易戰使各產業資本支出持續觀望，然食衣需求依然持續提升，根據Eurom...  ...                  0
# 3     展望2019年，雖中美貿易戰使各產業資本支出持續觀望，然食衣需求依然持續提升，根據Eurom...  ...                  1
# 4     展望2019年，雖中美貿易戰使各產業資本支出持續觀望，然食衣需求依然持續提升，根據Eurom...  ...                  1
# ...                                                 ...  ...                ...
# 4686  集團公佈銷售收入超過100億人民幣，大幅增長170%以上。集團表示銷售收入上升主要由於產業互...  ...                  0
# 4687  集團公佈銷售收入超過100億人民幣，大幅增長170%以上。集團表示銷售收入上升主要由於產業互...  ...                  1
# 4688  集團公佈銷售收入超過100億人民幣，大幅增長170%以上。集團表示銷售收入上升主要由於產業互...  ...                  0
# 4689  集團公佈銷售收入超過100億人民幣，大幅增長170%以上。集團表示銷售收入上升主要由於產業互...  ...                  1
# 4690  集團公佈銷售收入超過100億人民幣，大幅增長170%以上。集團表示銷售收入上升主要由於產業互...  ...                  1
#
# ...

# %%
report.to_excel('/content/drive/MyDrive/NTPU/NTCIR/FinNum3/EA_combine.xlsx', index = False)

# %%
print(report.groupby('claim_report').size())
# Out:
# claim_report
# 0    3684
# 1    1007
# dtype: int64

# %% [markdown]
# ---

# %%
class bcolors:
    OK = '\033[92m' #GREEN
    WARNING = '\033[93m' #YELLOW
    FAIL = '\033[91m' #RED
    RESET = '\033[0m' #RESET COLOR

# %%
def red(text):
  color = 'red' if True else 'black'
  return f'color:{color}'

# %%
for i in range(len(df)):
  string = df.loc[i, 'fragment']
  num = str(df.loc[i, 'target_numeral']).replace('.0', '')
  offset = df.loc[i, 'offset']
  array = []
  array.append(offset)
  array.append(int(offset)+len(num)) #放進陣列
  highlight = string[0:array[0]] + bcolors.FAIL + string[array[0]:array[1]] + bcolors.RESET + string[array[1]:len(string)]
  df.loc[i, 'fragment'] = highlight
df
# Out:
#                                                    text  ...                                           fragment
# 0     展望2019年，雖中美貿易戰使各產業資本支出持續觀望，然食衣需求依然持續提升，根據Eurom...  ...  展望2019年，雖中美貿易戰使各產業資本支出持續觀望，然食衣需求依然持續提升，根據Eurom...
# 1     展望2019年，雖中美貿易戰使各產業資本支出持續觀望，然食衣需求依然持續提升，根據Eurom...  ...  展望2019年，雖中美貿易戰使各產業資本支出持續觀望，然食衣需求依然持續提升，根據Eurom...
# 2     展望2019年，雖中美貿易戰使各產業資本支出持續觀望，然食衣需求依然持續提升，根據Eurom...  ...  展望2019年，雖中美貿易戰使各產業資本支出持續觀望，然食衣需求依然持續提升，根據Eurom...
# 3     展望2019年，雖中美貿易戰使各產業資本支出持續觀望，然食衣需求依然持續提升，根據Eurom...  ...  展望2019年，雖中美貿易戰使各產業資本支出持續觀望，然食衣需求依然持續提升，根據Eurom...
# 4     展望2019年，雖中美貿易戰使各產業資本支出持續觀望，然食衣需求依然持續提升，根據Eurom...  ...  展望2019年，雖中美貿易戰使各產業資本支出持續觀望，然食衣需求依然持續提升，根據Eurom...
# ...                                                 ...  ...                                                ...
# 4686  集團公佈銷售收入超過100億人民幣，大幅增長170%以上。集團表示銷售收入上升主要由於產業互...  ...  集團公佈銷售收入超過100億人民幣，大幅增長170%以上。集團表示銷售收入上升主要由於產業互...
# ...

# %%
pip install xlsxwriter
# Out:
# ...
#      |████████████████████████████████| 149 kB 27.2 MB/s
# ...

# %%
import xlsxwriter
df.to_excel('/content/drive/MyDrive/NTPU/NTCIR/FinNum3/dataset/EA_zh_combine_highlight.xlsx', engine='xlsxwriter')

# %% [markdown]
# ---

# %%
df = pd.read_excel('EA_zh_combine.xlsx')
df = df.drop(['Unnamed: 8', 'Unnamed: 10', '1: 前後相關聯都錯\n2: date category 錯\n3: 比例，(EX: 占多少% 或是多少錢)\n4: XX到XX (XX~XX)'], axis = 1)
df['category'] = report['category']
df['EA category'] = ''
df['fragment'] = df['text']
df = df[['text', 'target_numeral', 'offset', 'category', 'claim_report', 'claim_baseline', 'claim_dr', 'claim_aug', 'EA category', 'fragment']]
df['offset'] = df['offset'].astype('int64')
df['claim_report'] = df['claim_report'].astype('int64')
df['claim_baseline'] = df['claim_baseline'].astype('int64')
df['claim_dr'] = df['claim_dr'].astype('int64')
df['claim_aug'] = df['claim_aug'].astype('int64')
df

# %%
df.to_excel('EA_zh_combine2.xlsx')

# %%
def highlight():
    color = 'red' if text == num else 'black'
    return f'color:{color}'

# %%
def highlight():
  for i in range(len(df)):
    text = df.loc[i, 'fragment']
    num = str(df.loc[i, 'target_numeral'].astype('int64'))
    color = 'red' if num else 'black'
    return f'color:{color}'

# %%
for i in range(len(df)):
  text = df.loc[i, 'fragment']
  num = str(df.loc[i, 'target_numeral'].astype('int64'))
  new_df = df.head(10).style.applymap(highlight) #, subset=pd.IndexSlice[:,['fragment']]

# %%
df
# Out:
#                                                    text  ...                                           fragment
# 0     展望2019年，雖中美貿易戰使各產業資本支出持續觀望，然食衣需求依然持續提升，根據Eurom...  ...  展望2019年，雖中美貿易戰使各產業資本支出持續觀望，然食衣需求依然持續提升，根據Eurom...
# 1     展望2019年，雖中美貿易戰使各產業資本支出持續觀望，然食衣需求依然持續提升，根據Eurom...  ...  展望2019年，雖中美貿易戰使各產業資本支出持續觀望，然食衣需求依然持續提升，根據Eurom...
# 2     展望2019年，雖中美貿易戰使各產業資本支出持續觀望，然食衣需求依然持續提升，根據Eurom...  ...  展望2019年，雖中美貿易戰使各產業資本支出持續觀望，然食衣需求依然持續提升，根據Eurom...
# 3     展望2019年，雖中美貿易戰使各產業資本支出持續觀望，然食衣需求依然持續提升，根據Eurom...  ...  展望2019年，雖中美貿易戰使各產業資本支出持續觀望，然食衣需求依然持續提升，根據Eurom...
# 4     展望2019年，雖中美貿易戰使各產業資本支出持續觀望，然食衣需求依然持續提升，根據Eurom...  ...  展望2019年，雖中美貿易戰使各產業資本支出持續觀望，然食衣需求依然持續提升，根據Eurom...
# ...                                                 ...  ...                                                ...
# 4686  集團公佈銷售收入超過100億人民幣，大幅增長170%以上。集團表示銷售收入上升主要由於產業互...  ...  集團公佈銷售收入超過100億人民幣，大幅增長170%以上。集團表示銷售收入上升主要由於產業互...
# ...

# %%
(df.style
    #  .format('{:.1f}', subset='Fare')              # 將 Fare 欄位的數值顯示限制到小數後第一位
    #  .set_caption('五顏六色の鐵達尼號數據集')          # 添加一個標題輔助說明
    #  .hide_index()                                 # 隱藏索引（注意最左邊！）
    #  .bar('Age', vmin=0)                           # 將 Age 欄位依數值大小畫條狀圖
     .highlight_max('Survived')                      # 將 Survived 最大的值 highlight
     .background_gradient('Greens', subset='Fare')   # 將 Fare 欄位依數值畫綠色的 colormap
     .highlight_null()                               # 將整個 DataFrame 的空值顯示為紅色
)

# %%
new_df = df['fragment'].to_frame().head(10).style.applymap(highlight)
new_df
# Out:
# <style type="text/css">
# #T_b92d7_row0_col0, #T_b92d7_row1_col0, #T_b92d7_row2_col0, #T_b92d7_row3_col0, #T_b92d7_row4_col0, #T_b92d7_row5_col0, #T_b92d7_row6_col0, #T_b92d7_row7_col0, #T_b92d7_row8_col0, #T_b92d7_row9_col0 {
#   color: black;
# }
# </style>
# <table id="T_b92d7_" class="dataframe">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th class="col_heading level0 col0" >fragment</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_b92d7_level0_row0" class="row_heading level0 row0" >0</th>
# ...

# %% [markdown]
# ---

# %%
result = df
result
# Out:
#                                                    text  ...  claim_aug
# 0     展望2019年，雖中美貿易戰使各產業資本支出持續觀望，然食衣需求依然持續提升，根據Eurom...  ...          0
# 1     展望2019年，雖中美貿易戰使各產業資本支出持續觀望，然食衣需求依然持續提升，根據Eurom...  ...          1
# 2     展望2019年，雖中美貿易戰使各產業資本支出持續觀望，然食衣需求依然持續提升，根據Eurom...  ...          0
# 3     展望2019年，雖中美貿易戰使各產業資本支出持續觀望，然食衣需求依然持續提升，根據Eurom...  ...          1
# 4     展望2019年，雖中美貿易戰使各產業資本支出持續觀望，然食衣需求依然持續提升，根據Eurom...  ...          1
# ...                                                 ...  ...        ...
# 4686  集團公佈銷售收入超過100億人民幣，大幅增長170%以上。集團表示銷售收入上升主要由於產業互...  ...          0
# 4687  集團公佈銷售收入超過100億人民幣，大幅增長170%以上。集團表示銷售收入上升主要由於產業互...  ...          1
# 4688  集團公佈銷售收入超過100億人民幣，大幅增長170%以上。集團表示銷售收入上升主要由於產業互...  ...          0
# 4689  集團公佈銷售收入超過100億人民幣，大幅增長170%以上。集團表示銷售收入上升主要由於產業互...  ...          1
# 4690  集團公佈銷售收入超過100億人民幣，大幅增長170%以上。集團表示銷售收入上升主要由於產業互...  ...          1
#
# [4691 rows x 7 columns]

# %%
for i in range(len(result)):
  if result.loc[i, 'claim_report'] == result.loc[i, 'claim_baseline']:
    result.loc[i, 'claim_baseline'] = np.nan

  if result.loc[i, 'claim_report'] == result.loc[i, 'claim_dr']:
    result.loc[i, 'claim_dr'] = np.nan
  
  if result.loc[i, 'claim_report'] == result.loc[i, 'claim_aug']:
    result.loc[i, 'claim_aug'] = np.nan

# %%
result
# Out:
#                                                    text  ...  claim_aug
# 0     展望2019年，雖中美貿易戰使各產業資本支出持續觀望，然食衣需求依然持續提升，根據Eurom...  ...        NaN
# 1     展望2019年，雖中美貿易戰使各產業資本支出持續觀望，然食衣需求依然持續提升，根據Eurom...  ...        NaN
# 2     展望2019年，雖中美貿易戰使各產業資本支出持續觀望，然食衣需求依然持續提升，根據Eurom...  ...        NaN
# 3     展望2019年，雖中美貿易戰使各產業資本支出持續觀望，然食衣需求依然持續提升，根據Eurom...  ...        NaN
# 4     展望2019年，雖中美貿易戰使各產業資本支出持續觀望，然食衣需求依然持續提升，根據Eurom...  ...        NaN
# ...                                                 ...  ...        ...
# 4686  集團公佈銷售收入超過100億人民幣，大幅增長170%以上。集團表示銷售收入上升主要由於產業互...  ...        NaN
# 4687  集團公佈銷售收入超過100億人民幣，大幅增長170%以上。集團表示銷售收入上升主要由於產業互...  ...        NaN
# 4688  集團公佈銷售收入超過100億人民幣，大幅增長170%以上。集團表示銷售收入上升主要由於產業互...  ...        NaN
# 4689  集團公佈銷售收入超過100億人民幣，大幅增長170%以上。集團表示銷售收入上升主要由於產業互...  ...        NaN
# 4690  集團公佈銷售收入超過100億人民幣，大幅增長170%以上。集團表示銷售收入上升主要由於產業互...  ...        NaN
#
# [4691 rows x 7 columns]

# %%
result2 = result.groupby(['claim_report', 'claim_baseline', 'claim_dr', 'claim_aug'])

# %%
group = pd.DataFrame(result2.size())
group
# Out:
#                                                  0
# claim_report claim_baseline claim_dr claim_aug
# 0            1.0            1.0      1.0        93
# 1            0.0            0.0      0.0        56

# %%
result.to_excel('EA_zh_combine_analysis.xlsx')

# %%
result
# Out:
#                                                    text  ...  claim_aug
# 0     展望2019年，雖中美貿易戰使各產業資本支出持續觀望，然食衣需求依然持續提升，根據Eurom...  ...        NaN
# 1     展望2019年，雖中美貿易戰使各產業資本支出持續觀望，然食衣需求依然持續提升，根據Eurom...  ...        NaN
# 2     展望2019年，雖中美貿易戰使各產業資本支出持續觀望，然食衣需求依然持續提升，根據Eurom...  ...        NaN
# 3     展望2019年，雖中美貿易戰使各產業資本支出持續觀望，然食衣需求依然持續提升，根據Eurom...  ...        NaN
# 4     展望2019年，雖中美貿易戰使各產業資本支出持續觀望，然食衣需求依然持續提升，根據Eurom...  ...        NaN
# ...                                                 ...  ...        ...
# 4686  集團公佈銷售收入超過100億人民幣，大幅增長170%以上。集團表示銷售收入上升主要由於產業互...  ...        NaN
# 4687  集團公佈銷售收入超過100億人民幣，大幅增長170%以上。集團表示銷售收入上升主要由於產業互...  ...        NaN
# 4688  集團公佈銷售收入超過100億人民幣，大幅增長170%以上。集團表示銷售收入上升主要由於產業互...  ...        NaN
# 4689  集團公佈銷售收入超過100億人民幣，大幅增長170%以上。集團表示銷售收入上升主要由於產業互...  ...        NaN
# 4690  集團公佈銷售收入超過100億人民幣，大幅增長170%以上。集團表示銷售收入上升主要由於產業互...  ...        NaN
#
# [4691 rows x 7 columns]

# %%
result.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 4691 entries, 0 to 4690
# Data columns (total 7 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   text            4691 non-null   object
#  1   target_numeral  4691 non-null   float64
#  2   offset          4691 non-null   int64
#  3   claim_report    4691 non-null   int64
#  4   claim_baseline  220 non-null    float64
#  5   claim_dr        275 non-null    float64
#  6   claim_aug       225 non-null    float64
# dtypes: float64(4), int64(2), object(1)
# memory usage: 422.2+ KB

# %%
result3 = result.dropna(axis='index', how='all', subset=['claim_baseline','claim_dr','claim_aug'])
result3
# Out:
#                                                    text  ...  claim_aug
# 7     展望2019年，雖中美貿易戰使各產業資本支出持續觀望，然食衣需求依然持續提升，根據Eurom...  ...        NaN
# 15    近年來一般服飾走向低價、多樣化方向發展，高價機能衣因運動風氣盛行需求也有所增加，市場對服飾生...  ...        1.0
# 16    近年來一般服飾走向低價、多樣化方向發展，高價機能衣因運動風氣盛行需求也有所增加，市場對服飾生...  ...        1.0
# 17    近年來一般服飾走向低價、多樣化方向發展，高價機能衣因運動風氣盛行需求也有所增加，市場對服飾生...  ...        1.0
# 19    近年來一般服飾走向低價、多樣化方向發展，高價機能衣因運動風氣盛行需求也有所增加，市場對服飾生...  ...        NaN
# ...                                                 ...  ...        ...
# 4655  創意一年tapeout數目約20~30項，目前與人工智慧相關的數目為11個，包括1項為7nm...  ...        NaN
# 4656  創意一年tapeout數目約20~30項，目前與人工智慧相關的數目為11個，包括1項為7nm...  ...        NaN
# 4673  2019年環保耐蝕仍恐受限於中美貿易戰以及環保因素造成訂單穩定度較低，然馬來西亞新廠今年可望...  ...        NaN
# 4677  2019年環保耐蝕仍恐受限於中美貿易戰以及環保因素造成訂單穩定度較低，然馬來西亞新廠今年可望...  ...        0.0
# 4683  考量目前F1、F2躉購費率為台灣市場費率較高的風場，具投資價值，上緯為主要開發商，未來運維佔...  ...        1.0
#
# [351 rows x 7 columns]
